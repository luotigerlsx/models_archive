# %%
"""Convert TF v1 MobilenetV2 to TF v2 Keras."""

import os
from typing import Text, List, Dict, Tuple, Callable
from collections import defaultdict

import tensorflow as tf

# %%
from research.mobilenet.mobilenet_v3 import mobilenet_v3_large, mobilenet_v3_small, mobilenet_v3_edge_tpu
from research.mobilenet.mobilenet_trainer import _get_dataset_config, get_dataset

from research.mobilenet.configs import archs
MobileNetV3LargeConfig = archs.MobileNetV3LargeConfig

# %%
def _process_moving_average(ma_terms: List[Text]) -> List[Text]:
  """
    MobilenetV2/Conv/BatchNorm/moving_variance
    MobilenetV2/Conv/BatchNorm/moving_variance/ExponentialMovingAverage
    MobilenetV3/expanded_conv_9/project/BatchNorm/moving_mean/ExponentialMovingAverage
  Args:
    ma_terms: a list of names related to moving average

  Returns:
    a list of names after de-duplicating
  """
  output_list = list()
  base_name_set = set()
  replace_flag = False
  for item in ma_terms:
    base_name = item
    item_split = item.split('/')
    if 'moving_' in item_split[-2]:
      base_name = '/'.join(item_split[0:-1])
      replace_flag = True

    if base_name in base_name_set:
      if replace_flag:
        t_index = output_list.index(base_name)
        output_list[t_index] = item
    else:
      output_list.append(item)
      base_name_set.add(base_name)

    replace_flag = False

  return output_list


def _load_weights_from_ckpt(checkpoint_path: Text,
                            include_filters: List[Text],
                            exclude_filters: List[Text]
                            ) -> Dict[Text, tf.Tensor]:
  """Load all the weights stored in the checkpoint as {var_name: var_value}

  Args:
    checkpoint_path: path to the checkpoint file xxxxx.ckpt
    include_filters: list of keywords that determine which var_names should be
    kept in the output list
    exclude_filters: list of keywords that determine which var_names should be
    excluded from the output list

  Returns:
    A dictionary of {var_name: tensor values}
  """
  reader = tf.compat.v1.train.NewCheckpointReader(checkpoint_path)
  var_shape_map = reader.get_variable_to_shape_map()
  ma_terms = list()

  var_value_map = {}
  for item in var_shape_map:
    include_check = True
    if include_filters:
      include_check = any([to_check in item
                           for to_check in include_filters])
    exclude_check = True
    if exclude_filters:
      exclude_check = all([to_check not in item
                           for to_check in exclude_filters])

    if exclude_check and 'moving_' in item:
      ma_terms.append(item)
    elif include_check and exclude_check:
      var_value_map[item] = reader.get_tensor(item)

  processed_ma_terms = _process_moving_average(ma_terms)
  for p_item in processed_ma_terms:
    var_value_map[p_item] = reader.get_tensor(p_item)
  
  return var_value_map


def _decouple_layer_name(var_value_map: Dict[Text, tf.Tensor],
                         use_mv_average: bool = True
                         ) -> List[Tuple[Text, Text, tf.Tensor]]:
  """Sort the names of the weights by the layer they correspond to. The example
  names of the weightes:
    MobilenetV1/Conv2d_0/weights
    MobilenetV1/Conv2d_9_pointwise/weights
    MobilenetV1/Conv2d_9_pointwise/BatchNorm/beta
    MobilenetV1/Conv2d_9_pointwise/BatchNorm/beta/ExponentialMovingAverage

    Model_Name/Layer_Name/Component_Name[/Extra]

  Args:
    var_value_map: a dictionary of {var_name: tensor values}
    use_mv_average: whether `ExponentialMovingAverage` should be used. If this
    is true, the `ExponentialMovingAverage` related weightes should be included
    in  `var_value_map`.

  Returns:
    A list of (layer_num, layer_name, layer_component, weight_value)
  """
  layer_list = []
  for weight_name, weight_value in var_value_map.items():
    weight_name_split = weight_name.split('/')
    if use_mv_average and 'ExponentialMovingAverage' in weight_name:
      # MobilenetV1/Conv2d_9_pointwise/BatchNorm/beta/ExponentialMovingAverage
      layer_name = '/'.join(weight_name_split[1:-2])
      layer_component = '/'.join(weight_name_split[-2:-1])
    else:
      # MobilenetV1/Conv2d_9_pointwise/BatchNorm/beta
      layer_name = '/'.join(weight_name_split[1:-1])
      layer_component = '/'.join(weight_name_split[-1:])

    layer_list.append(
      (layer_name, layer_component, weight_value))

  return layer_list


def _layer_weights_list_to_map(
    layer_ordered_list: List[Tuple[Text, Text, tf.Tensor]]
) -> Dict[Text, List[tf.Tensor]]:
  """Organize same layer with multiple components into group.
  For example: BatchNorm has 'gamma', 'beta', 'moving_mean', 'moving_variance'

  Args:
    layer_ordered_list: A list of (layer_num, layer_name,
    layer_component, weight_value)

  Returns:
    A dictionary of {layer_name: layer_weights}
  """

  # define the vars order in Keras layer
  batchnorm_order = ['gamma', 'beta', 'moving_mean', 'moving_variance']
  dense_cnn_order = ['weights', 'biases']
  depthwise_order = ['depthwise_weights', 'biases']

  # Organize same layer with multiple components into group
  keras_weights = defaultdict(list)

  for (layer_name, layer_component, weight) in layer_ordered_list:
    keras_weights[layer_name].append((layer_component, weight))

  # Sort within each group. The ordering should be
  ordered_layer_weights = {}

  for group_name, group in keras_weights.items():
    # format of group: [(layer_component, weight)]
    if len(group) == 1:
      order_weight_group = [group[0][1]]
    else:
      group_len = len(group)
      order_weight_group = [0] * group_len

      if group_len == 2:
        target_order = dense_cnn_order
        if 'depthwise' in group_name:
          target_order = depthwise_order
      elif group_len == 4:
        target_order = batchnorm_order
      else:
        raise ValueError(
          'The number of components {} in a layer is not supported for {}'.format(
            group_len, group_name))

      for item_name, item_value in group:
        index = target_order.index(item_name)
        order_weight_group[index] = item_value

    ordered_layer_weights[group_name] = order_weight_group

  return ordered_layer_weights


def generate_layer_weights_map(checkpoint_path: Text,
                               include_filters: List[Text],
                               exclude_filters: List[Text],
                               use_mv_average: bool = True
                               ) -> Dict[Text, List[tf.Tensor]]:
  """Generate a dictionary of {layer_name: layer_weights} from checkpoint.

  Args:
    checkpoint_path: path to the checkpoint file xxxxx.ckpt
    include_filters: list of keywords that determine which var_names should be
    kept in the output list
    exclude_filters: list of keywords that determine which var_names should be
    excluded from the output list
    use_mv_average: whether `ExponentialMovingAverage` should be used. If this
    is true, the `ExponentialMovingAverage` related weightes should be included
    in  `var_value_map`.

  Returns:
    A dictionary of {layer_name: layer_weights}
  """
  var_value_map = _load_weights_from_ckpt(
    checkpoint_path=checkpoint_path,
    include_filters=include_filters,
    exclude_filters=exclude_filters)

  layer_ordered_list = _decouple_layer_name(
    var_value_map=var_value_map,
    use_mv_average=use_mv_average)

  ordered_layer_weights = _layer_weights_list_to_map(
    layer_ordered_list=layer_ordered_list)

  return ordered_layer_weights


def load_tf2_keras_model_weights(keras_model: tf.keras.Model,
                                 weights_map: Dict[Text, List[tf.Tensor]],
                                 name_map_fn: Callable
                                 ):
  """Load a TF2 Keras model with a {layer_name: layer_weights} dictionary
  generated from TF1 checkpoint.

  Args:
    keras_model: TF2 Keras model
    weights_map: a dictionary of {layer_name: layer_weights}
    name_map_fn: a function that convert TF2 layer name to TF1 layer name

  Returns:

  """
  trainable_layer_types = (
    tf.keras.layers.Conv2D,
    tf.keras.layers.BatchNormalization,
    tf.keras.layers.Dense,
    tf.keras.layers.DepthwiseConv2D,
  )

  trainable_layers = [layer for layer in keras_model.layers
                      if isinstance(layer, trainable_layer_types)]

  for layer in trainable_layers:
    name = layer.name
    tf1_name = name_map_fn(name)
    weight = weights_map[tf1_name]
    layer.set_weights(weight)


def save_keras_checkpoint(keras_model: tf.keras.Model,
                          save_path: Text,
                          save_format: Text = 'ckpt'
                          ):
  """Save a TF2 Keras model to a checkpoint.

  Args:
    keras_model: TF2 Keras model
    save_format: save format: ckpt and tf
    save_path: path to save the checkpoint

  Returns:

  """
  if save_format == 'ckpt':
    checkpoint = tf.train.Checkpoint(model=keras_model)
    manager = tf.train.CheckpointManager(checkpoint,
                                         directory=save_path,
                                         max_to_keep=1)
    manager.save()
  else:
    keras_model.save(save_path, save_format=save_format)

# %%
source_checkpoint = '/Users/luoshixin/Downloads/v3-large_224_0.75_float/pristine/model.ckpt-220000'
reader = tf.compat.v1.train.NewCheckpointReader(source_checkpoint)
var_shape_map = reader.get_variable_to_shape_map()

# %%
var_value_map = _load_weights_from_ckpt(source_checkpoint, 
                                 ['ExponentialMovingAverage'], 
                                 ['RMSProp', 'global_step', 'loss', 'Momentum'])

# %%
layer_ordered_list = _decouple_layer_name(var_value_map)

# %%
order_keras_weights = _layer_weights_list_to_map(layer_ordered_list)

# %%
sorted([(item[0], [iitem.shape for iitem in item[1]]) for item in order_keras_weights.items()])
# Out:
# [('Conv', [(3, 3, 3, 16)]),
#  ('Conv/BatchNorm', [(16,), (16,), (16,), (16,)]),
#  ('Conv_1', [(1, 1, 120, 720)]),
#  ('Conv_1/BatchNorm', [(720,), (720,), (720,), (720,)]),
#  ('Conv_2', [(1, 1, 720, 1280), (1280,)]),
#  ('Logits/Conv2d_1c_1x1', [(1, 1, 1280, 1001), (1001,)]),
#  ('expanded_conv/depthwise', [(3, 3, 16, 1)]),
#  ('expanded_conv/depthwise/BatchNorm', [(16,), (16,), (16,), (16,)]),
#  ('expanded_conv/project', [(1, 1, 16, 16)]),
#  ('expanded_conv/project/BatchNorm', [(16,), (16,), (16,), (16,)]),
#  ('expanded_conv_1/depthwise', [(3, 3, 64, 1)]),
#  ('expanded_conv_1/depthwise/BatchNorm', [(64,), (64,), (64,), (64,)]),
#  ('expanded_conv_1/expand', [(1, 1, 16, 64)]),
#  ('expanded_conv_1/expand/BatchNorm', [(64,), (64,), (64,), (64,)]),
#  ('expanded_conv_1/project', [(1, 1, 64, 24)]),
#  ('expanded_conv_1/project/BatchNorm', [(24,), (24,), (24,), (24,)]),
#  ('expanded_conv_10/depthwise', [(3, 3, 384, 1)]),
#  ('expanded_conv_10/depthwise/BatchNorm', [(384,), (384,), (384,), (384,)]),
#  ('expanded_conv_10/expand', [(1, 1, 64, 384)]),
#  ('expanded_conv_10/expand/BatchNorm', [(384,), (384,), (384,), (384,)]),
#  ('expanded_conv_10/project', [(1, 1, 384, 88)]),
#  ('expanded_conv_10/project/BatchNorm', [(88,), (88,), (88,), (88,)]),
#  ('expanded_conv_10/squeeze_excite/Conv', [(1, 1, 384, 96), (96,)]),
#  ('expanded_conv_10/squeeze_excite/Conv_1', [(1, 1, 96, 384), (384,)]),
#  ('expanded_conv_11/depthwise', [(3, 3, 528, 1)]),
#  ('expanded_conv_11/depthwise/BatchNorm', [(528,), (528,), (528,), (528,)]),
#  ('expanded_conv_11/expand', [(1, 1, 88, 528)]),
#  ('expanded_conv_11/expand/BatchNorm', [(528,), (528,), (528,), (528,)]),
#  ('expanded_conv_11/project', [(1, 1, 528, 88)]),
#  ('expanded_conv_11/project/BatchNorm', [(88,), (88,), (88,), (88,)]),
#  ('expanded_conv_11/squeeze_excite/Conv', [(1, 1, 528, 136), (136,)]),
#  ('expanded_conv_11/squeeze_excite/Conv_1', [(1, 1, 136, 528), (528,)]),
#  ('expanded_conv_12/depthwise', [(5, 5, 528, 1)]),
#  ('expanded_conv_12/depthwise/BatchNorm', [(528,), (528,), (528,), (528,)]),
#  ('expanded_conv_12/expand', [(1, 1, 88, 528)]),
#  ('expanded_conv_12/expand/BatchNorm', [(528,), (528,), (528,), (528,)]),
#  ('expanded_conv_12/project', [(1, 1, 528, 120)]),
#  ('expanded_conv_12/project/BatchNorm', [(120,), (120,), (120,), (120,)]),
#  ('expanded_conv_12/squeeze_excite/Conv', [(1, 1, 528, 136), (136,)]),
#  ('expanded_conv_12/squeeze_excite/Conv_1', [(1, 1, 136, 528), (528,)]),
#  ('expanded_conv_13/depthwise', [(5, 5, 720, 1)]),
#  ('expanded_conv_13/depthwise/BatchNorm', [(720,), (720,), (720,), (720,)]),
#  ('expanded_conv_13/expand', [(1, 1, 120, 720)]),
#  ('expanded_conv_13/expand/BatchNorm', [(720,), (720,), (720,), (720,)]),
#  ('expanded_conv_13/project', [(1, 1, 720, 120)]),
#  ('expanded_conv_13/project/BatchNorm', [(120,), (120,), (120,), (120,)]),
#  ('expanded_conv_13/squeeze_excite/Conv', [(1, 1, 720, 184), (184,)]),
#  ('expanded_conv_13/squeeze_excite/Conv_1', [(1, 1, 184, 720), (720,)]),
#  ('expanded_conv_14/depthwise', [(5, 5, 720, 1)]),
#  ('expanded_conv_14/depthwise/BatchNorm', [(720,), (720,), (720,), (720,)]),
#  ('expanded_conv_14/expand', [(1, 1, 120, 720)]),
#  ('expanded_conv_14/expand/BatchNorm', [(720,), (720,), (720,), (720,)]),
#  ('expanded_conv_14/project', [(1, 1, 720, 120)]),
#  ('expanded_conv_14/project/BatchNorm', [(120,), (120,), (120,), (120,)]),
#  ('expanded_conv_14/squeeze_excite/Conv', [(1, 1, 720, 184), (184,)]),
#  ('expanded_conv_14/squeeze_excite/Conv_1', [(1, 1, 184, 720), (720,)]),
#  ('expanded_conv_2/depthwise', [(3, 3, 72, 1)]),
#  ('expanded_conv_2/depthwise/BatchNorm', [(72,), (72,), (72,), (72,)]),
#  ('expanded_conv_2/expand', [(1, 1, 24, 72)]),
#  ('expanded_conv_2/expand/BatchNorm', [(72,), (72,), (72,), (72,)]),
#  ('expanded_conv_2/project', [(1, 1, 72, 24)]),
#  ('expanded_conv_2/project/BatchNorm', [(24,), (24,), (24,), (24,)]),
#  ('expanded_conv_3/depthwise', [(5, 5, 72, 1)]),
#  ('expanded_conv_3/depthwise/BatchNorm', [(72,), (72,), (72,), (72,)]),
#  ('expanded_conv_3/expand', [(1, 1, 24, 72)]),
#  ('expanded_conv_3/expand/BatchNorm', [(72,), (72,), (72,), (72,)]),
#  ('expanded_conv_3/project', [(1, 1, 72, 32)]),
#  ('expanded_conv_3/project/BatchNorm', [(32,), (32,), (32,), (32,)]),
#  ('expanded_conv_3/squeeze_excite/Conv', [(1, 1, 72, 24), (24,)]),
#  ('expanded_conv_3/squeeze_excite/Conv_1', [(1, 1, 24, 72), (72,)]),
#  ('expanded_conv_4/depthwise', [(5, 5, 96, 1)]),
#  ('expanded_conv_4/depthwise/BatchNorm', [(96,), (96,), (96,), (96,)]),
#  ('expanded_conv_4/expand', [(1, 1, 32, 96)]),
#  ('expanded_conv_4/expand/BatchNorm', [(96,), (96,), (96,), (96,)]),
#  ('expanded_conv_4/project', [(1, 1, 96, 32)]),
#  ('expanded_conv_4/project/BatchNorm', [(32,), (32,), (32,), (32,)]),
#  ('expanded_conv_4/squeeze_excite/Conv', [(1, 1, 96, 24), (24,)]),
#  ('expanded_conv_4/squeeze_excite/Conv_1', [(1, 1, 24, 96), (96,)]),
#  ('expanded_conv_5/depthwise', [(5, 5, 96, 1)]),
#  ('expanded_conv_5/depthwise/BatchNorm', [(96,), (96,), (96,), (96,)]),
#  ('expanded_conv_5/expand', [(1, 1, 32, 96)]),
#  ('expanded_conv_5/expand/BatchNorm', [(96,), (96,), (96,), (96,)]),
#  ('expanded_conv_5/project', [(1, 1, 96, 32)]),
#  ('expanded_conv_5/project/BatchNorm', [(32,), (32,), (32,), (32,)]),
#  ('expanded_conv_5/squeeze_excite/Conv', [(1, 1, 96, 24), (24,)]),
#  ('expanded_conv_5/squeeze_excite/Conv_1', [(1, 1, 24, 96), (96,)]),
#  ('expanded_conv_6/depthwise', [(3, 3, 192, 1)]),
#  ('expanded_conv_6/depthwise/BatchNorm', [(192,), (192,), (192,), (192,)]),
#  ('expanded_conv_6/expand', [(1, 1, 32, 192)]),
#  ('expanded_conv_6/expand/BatchNorm', [(192,), (192,), (192,), (192,)]),
#  ('expanded_conv_6/project', [(1, 1, 192, 64)]),
#  ('expanded_conv_6/project/BatchNorm', [(64,), (64,), (64,), (64,)]),
#  ('expanded_conv_7/depthwise', [(3, 3, 160, 1)]),
#  ('expanded_conv_7/depthwise/BatchNorm', [(160,), (160,), (160,), (160,)]),
#  ('expanded_conv_7/expand', [(1, 1, 64, 160)]),
#  ('expanded_conv_7/expand/BatchNorm', [(160,), (160,), (160,), (160,)]),
#  ('expanded_conv_7/project', [(1, 1, 160, 64)]),
#  ('expanded_conv_7/project/BatchNorm', [(64,), (64,), (64,), (64,)]),
#  ('expanded_conv_8/depthwise', [(3, 3, 144, 1)]),
#  ('expanded_conv_8/depthwise/BatchNorm', [(144,), (144,), (144,), (144,)]),
#  ('expanded_conv_8/expand', [(1, 1, 64, 144)]),
#  ('expanded_conv_8/expand/BatchNorm', [(144,), (144,), (144,), (144,)]),
#  ('expanded_conv_8/project', [(1, 1, 144, 64)]),
#  ('expanded_conv_8/project/BatchNorm', [(64,), (64,), (64,), (64,)]),
#  ('expanded_conv_9/depthwise', [(3, 3, 144, 1)]),
#  ('expanded_conv_9/depthwise/BatchNorm', [(144,), (144,), (144,), (144,)]),
#  ('expanded_conv_9/expand', [(1, 1, 64, 144)]),
#  ('expanded_conv_9/expand/BatchNorm', [(144,), (144,), (144,), (144,)]),
#  ('expanded_conv_9/project', [(1, 1, 144, 64)]),
#  ('expanded_conv_9/project/BatchNorm', [(64,), (64,), (64,), (64,)])]

# %%
def mobinetv3_tf1_tf2_name_convert(tf2_layer_name: Text) -> Text:
  """Convert TF2 layer name to TF1 layer name. Examples:
  Conv2d_0 -> Conv
  Conv2d_0/batch_norm -> Conv/BatchNorm
  Conv2d_16 -> Conv_1
  Conv2d_16/batch_norm -> Conv_1/BatchNorm
  top/Conv2d_1x1 ->  Conv_2

  expanded_conv_1/project -> expanded_conv/project
  expanded_conv_1/depthwise -> expanded_conv/depthwise
  expanded_conv_2/expand -> expanded_conv_1/expand
  expanded_conv_2/expand/batch_norm -> expanded_conv_1/expand/BatchNorm
  expanded_conv_2/project -> expanded_conv_1/project
  expanded_conv_2/depthwise -> expanded_conv_1/depthwise
  expanded_conv_5/squeeze_excite/squeeze -> expanded_conv_4/squeeze_excite/Conv
  expanded_conv_5/squeeze_excite/excite -> expanded_conv_4/squeeze_excite/Conv_1

  top/Conv2d_1x1_output -> Logits/Conv2d_1c_1x1

  Args:
    tf2_layer_name: name of TF2 layer

  Returns:
    name of TF1 layer
  """

  if 'top/Conv2d_1x1_output' in tf2_layer_name:
    tf1_layer_name = 'Logits/Conv2d_1c_1x1'
  elif 'top/Conv2d_1x1' in tf2_layer_name:
    tf1_layer_name = 'Conv_2'
  else:
    if 'batch_norm' in tf2_layer_name:
      tf2_layer_name = tf2_layer_name.replace('batch_norm', 'BatchNorm')
    # process layer number
    tf2_layer_name_split = tf2_layer_name.split('/')
    layer_num_re, reminder = tf2_layer_name_split[0], tf2_layer_name_split[1:]
    layer_num_re_split = layer_num_re.split('_')
    layer_type = '_'.join(layer_num_re_split[0:-1])
    layer_num = int(layer_num_re_split[-1])

    # process layer type and layer number
    if layer_type == 'Conv2d':
      layer_type = 'Conv'
      if layer_num == 0:
        target_num = ''
      else:
        target_num = '1'
    elif layer_type == 'expanded_conv':
      if layer_num == 1:
        target_num = ''
      else:
        target_num = str(layer_num - 1)
    else:
      raise ValueError('The layer number and type combination is not '
                       'supported: {}, {}'.format(layer_type, str(layer_num)))

    # process squeeze_excite layer
    if 'squeeze_excite' in ''.join(reminder):
      if reminder[-1] == 'squeeze':
        reminder[-1] = 'Conv'
      elif reminder[-1] == 'excite':
        reminder[-1] = 'Conv_1'

    if target_num:
      tf1_layer_name = '/'.join(['_'.join([layer_type, target_num])] + reminder)
    else:
      tf1_layer_name = '/'.join([layer_type] + reminder)

  return tf1_layer_name

# %%
config = archs.MobileNetV3EdgeTPUConfig()
config.width_multiplier = 0.75
model = mobilenet_v3_edge_tpu(config=config)
model.summary(line_length=100)
# Out:
# Model: "MobileNetV3EdgeTPU"
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# Input (InputLayer)               [(None, 224, 224, 3)] 0
# ____________________________________________________________________________________________________
# Conv2d_0_0 (Conv2D)              (None, 112, 112, 24)  648         Input[0][0]
# ____________________________________________________________________________________________________
# Conv2d_0_0/batch_norm (BatchNorm (None, 112, 112, 24)  96          Conv2d_0_0[0][0]
# ____________________________________________________________________________________________________
# Conv2d_0_0/relu (Activation)     (None, 112, 112, 24)  0           Conv2d_0_0/batch_norm[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_1/project (Conv2D) (None, 112, 112, 16)  384         Conv2d_0_0/relu[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_1/project/batch_no (None, 112, 112, 16)  64          expanded_conv_1/project[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_2/expand (Conv2D)  (None, 56, 56, 128)   18432       expanded_conv_1/project/batch_nor
# ____________________________________________________________________________________________________
# expanded_conv_2/expand/batch_nor (None, 56, 56, 128)   512         expanded_conv_2/expand[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_2/expand/relu (Act (None, 56, 56, 128)   0           expanded_conv_2/expand/batch_norm
# ____________________________________________________________________________________________________
# expanded_conv_2/project (Conv2D) (None, 56, 56, 24)    3072        expanded_conv_2/expand/relu[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_2/project/batch_no (None, 56, 56, 24)    96          expanded_conv_2/project[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_3/expand (Conv2D)  (None, 56, 56, 96)    20736       expanded_conv_2/project/batch_nor
# ____________________________________________________________________________________________________
# expanded_conv_3/expand/batch_nor (None, 56, 56, 96)    384         expanded_conv_3/expand[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_3/expand/relu (Act (None, 56, 56, 96)    0           expanded_conv_3/expand/batch_norm
# ____________________________________________________________________________________________________
# expanded_conv_3/project (Conv2D) (None, 56, 56, 24)    2304        expanded_conv_3/expand/relu[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_3/project/batch_no (None, 56, 56, 24)    96          expanded_conv_3/project[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_3/add (Add)        (None, 56, 56, 24)    0           expanded_conv_2/project/batch_nor
#                                                                    expanded_conv_3/project/batch_nor
# ____________________________________________________________________________________________________
# expanded_conv_4/expand (Conv2D)  (None, 56, 56, 96)    20736       expanded_conv_3/add[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_4/expand/batch_nor (None, 56, 56, 96)    384         expanded_conv_4/expand[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_4/expand/relu (Act (None, 56, 56, 96)    0           expanded_conv_4/expand/batch_norm
# ____________________________________________________________________________________________________
# expanded_conv_4/project (Conv2D) (None, 56, 56, 24)    2304        expanded_conv_4/expand/relu[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_4/project/batch_no (None, 56, 56, 24)    96          expanded_conv_4/project[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_4/add (Add)        (None, 56, 56, 24)    0           expanded_conv_3/add[0][0]
#                                                                    expanded_conv_4/project/batch_nor
# ____________________________________________________________________________________________________
# expanded_conv_5/expand (Conv2D)  (None, 56, 56, 96)    20736       expanded_conv_4/add[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_5/expand/batch_nor (None, 56, 56, 96)    384         expanded_conv_5/expand[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_5/expand/relu (Act (None, 56, 56, 96)    0           expanded_conv_5/expand/batch_norm
# ____________________________________________________________________________________________________
# expanded_conv_5/project (Conv2D) (None, 56, 56, 24)    2304        expanded_conv_5/expand/relu[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_5/project/batch_no (None, 56, 56, 24)    96          expanded_conv_5/project[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_5/add (Add)        (None, 56, 56, 24)    0           expanded_conv_4/add[0][0]
#                                                                    expanded_conv_5/project/batch_nor
# ____________________________________________________________________________________________________
# expanded_conv_6/expand (Conv2D)  (None, 28, 28, 192)   41472       expanded_conv_5/add[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_6/expand/batch_nor (None, 28, 28, 192)   768         expanded_conv_6/expand[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_6/expand/relu (Act (None, 28, 28, 192)   0           expanded_conv_6/expand/batch_norm
# ____________________________________________________________________________________________________
# expanded_conv_6/project (Conv2D) (None, 28, 28, 40)    7680        expanded_conv_6/expand/relu[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_6/project/batch_no (None, 28, 28, 40)    160         expanded_conv_6/project[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_7/expand (Conv2D)  (None, 28, 28, 160)   57600       expanded_conv_6/project/batch_nor
# ____________________________________________________________________________________________________
# expanded_conv_7/expand/batch_nor (None, 28, 28, 160)   640         expanded_conv_7/expand[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_7/expand/relu (Act (None, 28, 28, 160)   0           expanded_conv_7/expand/batch_norm
# ____________________________________________________________________________________________________
# expanded_conv_7/project (Conv2D) (None, 28, 28, 40)    6400        expanded_conv_7/expand/relu[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_7/project/batch_no (None, 28, 28, 40)    160         expanded_conv_7/project[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_7/add (Add)        (None, 28, 28, 40)    0           expanded_conv_6/project/batch_nor
#                                                                    expanded_conv_7/project/batch_nor
# ____________________________________________________________________________________________________
# expanded_conv_8/expand (Conv2D)  (None, 28, 28, 160)   57600       expanded_conv_7/add[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_8/expand/batch_nor (None, 28, 28, 160)   640         expanded_conv_8/expand[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_8/expand/relu (Act (None, 28, 28, 160)   0           expanded_conv_8/expand/batch_norm
# ____________________________________________________________________________________________________
# expanded_conv_8/project (Conv2D) (None, 28, 28, 40)    6400        expanded_conv_8/expand/relu[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_8/project/batch_no (None, 28, 28, 40)    160         expanded_conv_8/project[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_8/add (Add)        (None, 28, 28, 40)    0           expanded_conv_7/add[0][0]
#                                                                    expanded_conv_8/project/batch_nor
# ____________________________________________________________________________________________________
# expanded_conv_9/expand (Conv2D)  (None, 28, 28, 160)   57600       expanded_conv_8/add[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_9/expand/batch_nor (None, 28, 28, 160)   640         expanded_conv_9/expand[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_9/expand/relu (Act (None, 28, 28, 160)   0           expanded_conv_9/expand/batch_norm
# ____________________________________________________________________________________________________
# expanded_conv_9/project (Conv2D) (None, 28, 28, 40)    6400        expanded_conv_9/expand/relu[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_9/project/batch_no (None, 28, 28, 40)    160         expanded_conv_9/project[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_9/add (Add)        (None, 28, 28, 40)    0           expanded_conv_8/add[0][0]
#                                                                    expanded_conv_9/project/batch_nor
# ____________________________________________________________________________________________________
# expanded_conv_10/expand (Conv2D) (None, 28, 28, 320)   12800       expanded_conv_9/add[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_10/expand/batch_no (None, 28, 28, 320)   1280        expanded_conv_10/expand[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_10/expand/relu (Ac (None, 28, 28, 320)   0           expanded_conv_10/expand/batch_nor
# ____________________________________________________________________________________________________
# expanded_conv_10/depthwise (Dept (None, 14, 14, 320)   2880        expanded_conv_10/expand/relu[0][0
# ____________________________________________________________________________________________________
# expanded_conv_10/depthwise/batch (None, 14, 14, 320)   1280        expanded_conv_10/depthwise[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_10/depthwise/relu  (None, 14, 14, 320)   0           expanded_conv_10/depthwise/batch_
# ____________________________________________________________________________________________________
# expanded_conv_10/project (Conv2D (None, 14, 14, 72)    23040       expanded_conv_10/depthwise/relu[0
# ____________________________________________________________________________________________________
# expanded_conv_10/project/batch_n (None, 14, 14, 72)    288         expanded_conv_10/project[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_11/expand (Conv2D) (None, 14, 14, 288)   20736       expanded_conv_10/project/batch_no
# ____________________________________________________________________________________________________
# expanded_conv_11/expand/batch_no (None, 14, 14, 288)   1152        expanded_conv_11/expand[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_11/expand/relu (Ac (None, 14, 14, 288)   0           expanded_conv_11/expand/batch_nor
# ____________________________________________________________________________________________________
# expanded_conv_11/depthwise (Dept (None, 14, 14, 288)   2592        expanded_conv_11/expand/relu[0][0
# ____________________________________________________________________________________________________
# expanded_conv_11/depthwise/batch (None, 14, 14, 288)   1152        expanded_conv_11/depthwise[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_11/depthwise/relu  (None, 14, 14, 288)   0           expanded_conv_11/depthwise/batch_
# ____________________________________________________________________________________________________
# expanded_conv_11/project (Conv2D (None, 14, 14, 72)    20736       expanded_conv_11/depthwise/relu[0
# ____________________________________________________________________________________________________
# expanded_conv_11/project/batch_n (None, 14, 14, 72)    288         expanded_conv_11/project[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_11/add (Add)       (None, 14, 14, 72)    0           expanded_conv_10/project/batch_no
#                                                                    expanded_conv_11/project/batch_no
# ____________________________________________________________________________________________________
# expanded_conv_12/expand (Conv2D) (None, 14, 14, 288)   20736       expanded_conv_11/add[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_12/expand/batch_no (None, 14, 14, 288)   1152        expanded_conv_12/expand[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_12/expand/relu (Ac (None, 14, 14, 288)   0           expanded_conv_12/expand/batch_nor
# ____________________________________________________________________________________________________
# expanded_conv_12/depthwise (Dept (None, 14, 14, 288)   2592        expanded_conv_12/expand/relu[0][0
# ____________________________________________________________________________________________________
# expanded_conv_12/depthwise/batch (None, 14, 14, 288)   1152        expanded_conv_12/depthwise[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_12/depthwise/relu  (None, 14, 14, 288)   0           expanded_conv_12/depthwise/batch_
# ____________________________________________________________________________________________________
# expanded_conv_12/project (Conv2D (None, 14, 14, 72)    20736       expanded_conv_12/depthwise/relu[0
# ____________________________________________________________________________________________________
# expanded_conv_12/project/batch_n (None, 14, 14, 72)    288         expanded_conv_12/project[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_12/add (Add)       (None, 14, 14, 72)    0           expanded_conv_11/add[0][0]
#                                                                    expanded_conv_12/project/batch_no
# ____________________________________________________________________________________________________
# expanded_conv_13/expand (Conv2D) (None, 14, 14, 288)   20736       expanded_conv_12/add[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_13/expand/batch_no (None, 14, 14, 288)   1152        expanded_conv_13/expand[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_13/expand/relu (Ac (None, 14, 14, 288)   0           expanded_conv_13/expand/batch_nor
# ____________________________________________________________________________________________________
# expanded_conv_13/depthwise (Dept (None, 14, 14, 288)   2592        expanded_conv_13/expand/relu[0][0
# ____________________________________________________________________________________________________
# expanded_conv_13/depthwise/batch (None, 14, 14, 288)   1152        expanded_conv_13/depthwise[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_13/depthwise/relu  (None, 14, 14, 288)   0           expanded_conv_13/depthwise/batch_
# ____________________________________________________________________________________________________
# expanded_conv_13/project (Conv2D (None, 14, 14, 72)    20736       expanded_conv_13/depthwise/relu[0
# ____________________________________________________________________________________________________
# expanded_conv_13/project/batch_n (None, 14, 14, 72)    288         expanded_conv_13/project[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_13/add (Add)       (None, 14, 14, 72)    0           expanded_conv_12/add[0][0]
#                                                                    expanded_conv_13/project/batch_no
# ____________________________________________________________________________________________________
# expanded_conv_14/expand (Conv2D) (None, 14, 14, 576)   41472       expanded_conv_13/add[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_14/expand/batch_no (None, 14, 14, 576)   2304        expanded_conv_14/expand[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_14/expand/relu (Ac (None, 14, 14, 576)   0           expanded_conv_14/expand/batch_nor
# ____________________________________________________________________________________________________
# expanded_conv_14/depthwise (Dept (None, 14, 14, 576)   5184        expanded_conv_14/expand/relu[0][0
# ____________________________________________________________________________________________________
# expanded_conv_14/depthwise/batch (None, 14, 14, 576)   2304        expanded_conv_14/depthwise[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_14/depthwise/relu  (None, 14, 14, 576)   0           expanded_conv_14/depthwise/batch_
# ____________________________________________________________________________________________________
# expanded_conv_14/project (Conv2D (None, 14, 14, 72)    41472       expanded_conv_14/depthwise/relu[0
# ____________________________________________________________________________________________________
# expanded_conv_14/project/batch_n (None, 14, 14, 72)    288         expanded_conv_14/project[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_15/expand (Conv2D) (None, 14, 14, 288)   20736       expanded_conv_14/project/batch_no
# ____________________________________________________________________________________________________
# expanded_conv_15/expand/batch_no (None, 14, 14, 288)   1152        expanded_conv_15/expand[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_15/expand/relu (Ac (None, 14, 14, 288)   0           expanded_conv_15/expand/batch_nor
# ____________________________________________________________________________________________________
# expanded_conv_15/depthwise (Dept (None, 14, 14, 288)   2592        expanded_conv_15/expand/relu[0][0
# ____________________________________________________________________________________________________
# expanded_conv_15/depthwise/batch (None, 14, 14, 288)   1152        expanded_conv_15/depthwise[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_15/depthwise/relu  (None, 14, 14, 288)   0           expanded_conv_15/depthwise/batch_
# ____________________________________________________________________________________________________
# expanded_conv_15/project (Conv2D (None, 14, 14, 72)    20736       expanded_conv_15/depthwise/relu[0
# ____________________________________________________________________________________________________
# expanded_conv_15/project/batch_n (None, 14, 14, 72)    288         expanded_conv_15/project[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_15/add (Add)       (None, 14, 14, 72)    0           expanded_conv_14/project/batch_no
#                                                                    expanded_conv_15/project/batch_no
# ____________________________________________________________________________________________________
# expanded_conv_16/expand (Conv2D) (None, 14, 14, 288)   20736       expanded_conv_15/add[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_16/expand/batch_no (None, 14, 14, 288)   1152        expanded_conv_16/expand[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_16/expand/relu (Ac (None, 14, 14, 288)   0           expanded_conv_16/expand/batch_nor
# ____________________________________________________________________________________________________
# expanded_conv_16/depthwise (Dept (None, 14, 14, 288)   2592        expanded_conv_16/expand/relu[0][0
# ____________________________________________________________________________________________________
# expanded_conv_16/depthwise/batch (None, 14, 14, 288)   1152        expanded_conv_16/depthwise[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_16/depthwise/relu  (None, 14, 14, 288)   0           expanded_conv_16/depthwise/batch_
# ____________________________________________________________________________________________________
# expanded_conv_16/project (Conv2D (None, 14, 14, 72)    20736       expanded_conv_16/depthwise/relu[0
# ____________________________________________________________________________________________________
# expanded_conv_16/project/batch_n (None, 14, 14, 72)    288         expanded_conv_16/project[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_16/add (Add)       (None, 14, 14, 72)    0           expanded_conv_15/add[0][0]
#                                                                    expanded_conv_16/project/batch_no
# ____________________________________________________________________________________________________
# expanded_conv_17/expand (Conv2D) (None, 14, 14, 288)   20736       expanded_conv_16/add[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_17/expand/batch_no (None, 14, 14, 288)   1152        expanded_conv_17/expand[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_17/expand/relu (Ac (None, 14, 14, 288)   0           expanded_conv_17/expand/batch_nor
# ____________________________________________________________________________________________________
# expanded_conv_17/depthwise (Dept (None, 14, 14, 288)   2592        expanded_conv_17/expand/relu[0][0
# ____________________________________________________________________________________________________
# expanded_conv_17/depthwise/batch (None, 14, 14, 288)   1152        expanded_conv_17/depthwise[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_17/depthwise/relu  (None, 14, 14, 288)   0           expanded_conv_17/depthwise/batch_
# ____________________________________________________________________________________________________
# expanded_conv_17/project (Conv2D (None, 14, 14, 72)    20736       expanded_conv_17/depthwise/relu[0
# ____________________________________________________________________________________________________
# expanded_conv_17/project/batch_n (None, 14, 14, 72)    288         expanded_conv_17/project[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_17/add (Add)       (None, 14, 14, 72)    0           expanded_conv_16/add[0][0]
#                                                                    expanded_conv_17/project/batch_no
# ____________________________________________________________________________________________________
# expanded_conv_18/expand (Conv2D) (None, 14, 14, 576)   41472       expanded_conv_17/add[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_18/expand/batch_no (None, 14, 14, 576)   2304        expanded_conv_18/expand[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_18/expand/relu (Ac (None, 14, 14, 576)   0           expanded_conv_18/expand/batch_nor
# ____________________________________________________________________________________________________
# expanded_conv_18/depthwise (Dept (None, 7, 7, 576)     14400       expanded_conv_18/expand/relu[0][0
# ____________________________________________________________________________________________________
# expanded_conv_18/depthwise/batch (None, 7, 7, 576)     2304        expanded_conv_18/depthwise[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_18/depthwise/relu  (None, 7, 7, 576)     0           expanded_conv_18/depthwise/batch_
# ____________________________________________________________________________________________________
# expanded_conv_18/project (Conv2D (None, 7, 7, 120)     69120       expanded_conv_18/depthwise/relu[0
# ____________________________________________________________________________________________________
# expanded_conv_18/project/batch_n (None, 7, 7, 120)     480         expanded_conv_18/project[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_19/expand (Conv2D) (None, 7, 7, 480)     57600       expanded_conv_18/project/batch_no
# ____________________________________________________________________________________________________
# expanded_conv_19/expand/batch_no (None, 7, 7, 480)     1920        expanded_conv_19/expand[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_19/expand/relu (Ac (None, 7, 7, 480)     0           expanded_conv_19/expand/batch_nor
# ____________________________________________________________________________________________________
# expanded_conv_19/depthwise (Dept (None, 7, 7, 480)     12000       expanded_conv_19/expand/relu[0][0
# ____________________________________________________________________________________________________
# expanded_conv_19/depthwise/batch (None, 7, 7, 480)     1920        expanded_conv_19/depthwise[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_19/depthwise/relu  (None, 7, 7, 480)     0           expanded_conv_19/depthwise/batch_
# ____________________________________________________________________________________________________
# expanded_conv_19/project (Conv2D (None, 7, 7, 120)     57600       expanded_conv_19/depthwise/relu[0
# ____________________________________________________________________________________________________
# expanded_conv_19/project/batch_n (None, 7, 7, 120)     480         expanded_conv_19/project[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_19/add (Add)       (None, 7, 7, 120)     0           expanded_conv_18/project/batch_no
#                                                                    expanded_conv_19/project/batch_no
# ____________________________________________________________________________________________________
# expanded_conv_20/expand (Conv2D) (None, 7, 7, 480)     57600       expanded_conv_19/add[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_20/expand/batch_no (None, 7, 7, 480)     1920        expanded_conv_20/expand[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_20/expand/relu (Ac (None, 7, 7, 480)     0           expanded_conv_20/expand/batch_nor
# ____________________________________________________________________________________________________
# expanded_conv_20/depthwise (Dept (None, 7, 7, 480)     12000       expanded_conv_20/expand/relu[0][0
# ____________________________________________________________________________________________________
# expanded_conv_20/depthwise/batch (None, 7, 7, 480)     1920        expanded_conv_20/depthwise[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_20/depthwise/relu  (None, 7, 7, 480)     0           expanded_conv_20/depthwise/batch_
# ____________________________________________________________________________________________________
# expanded_conv_20/project (Conv2D (None, 7, 7, 120)     57600       expanded_conv_20/depthwise/relu[0
# ____________________________________________________________________________________________________
# expanded_conv_20/project/batch_n (None, 7, 7, 120)     480         expanded_conv_20/project[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_20/add (Add)       (None, 7, 7, 120)     0           expanded_conv_19/add[0][0]
#                                                                    expanded_conv_20/project/batch_no
# ____________________________________________________________________________________________________
# expanded_conv_21/expand (Conv2D) (None, 7, 7, 480)     57600       expanded_conv_20/add[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_21/expand/batch_no (None, 7, 7, 480)     1920        expanded_conv_21/expand[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_21/expand/relu (Ac (None, 7, 7, 480)     0           expanded_conv_21/expand/batch_nor
# ____________________________________________________________________________________________________
# expanded_conv_21/depthwise (Dept (None, 7, 7, 480)     12000       expanded_conv_21/expand/relu[0][0
# ____________________________________________________________________________________________________
# expanded_conv_21/depthwise/batch (None, 7, 7, 480)     1920        expanded_conv_21/depthwise[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_21/depthwise/relu  (None, 7, 7, 480)     0           expanded_conv_21/depthwise/batch_
# ____________________________________________________________________________________________________
# expanded_conv_21/project (Conv2D (None, 7, 7, 120)     57600       expanded_conv_21/depthwise/relu[0
# ____________________________________________________________________________________________________
# expanded_conv_21/project/batch_n (None, 7, 7, 120)     480         expanded_conv_21/project[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_21/add (Add)       (None, 7, 7, 120)     0           expanded_conv_20/add[0][0]
#                                                                    expanded_conv_21/project/batch_no
# ____________________________________________________________________________________________________
# expanded_conv_22/expand (Conv2D) (None, 7, 7, 960)     115200      expanded_conv_21/add[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_22/expand/batch_no (None, 7, 7, 960)     3840        expanded_conv_22/expand[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_22/expand/relu (Ac (None, 7, 7, 960)     0           expanded_conv_22/expand/batch_nor
# ____________________________________________________________________________________________________
# expanded_conv_22/depthwise (Dept (None, 7, 7, 960)     8640        expanded_conv_22/expand/relu[0][0
# ____________________________________________________________________________________________________
# expanded_conv_22/depthwise/batch (None, 7, 7, 960)     3840        expanded_conv_22/depthwise[0][0]
# ____________________________________________________________________________________________________
# expanded_conv_22/depthwise/relu  (None, 7, 7, 960)     0           expanded_conv_22/depthwise/batch_
# ____________________________________________________________________________________________________
# expanded_conv_22/project (Conv2D (None, 7, 7, 144)     138240      expanded_conv_22/depthwise/relu[0
# ____________________________________________________________________________________________________
# expanded_conv_22/project/batch_n (None, 7, 7, 144)     576         expanded_conv_22/project[0][0]
# ____________________________________________________________________________________________________
# Conv2d_23_1 (Conv2D)             (None, 7, 7, 1280)    184320      expanded_conv_22/project/batch_no
# ____________________________________________________________________________________________________
# Conv2d_23_1/batch_norm (BatchNor (None, 7, 7, 1280)    5120        Conv2d_23_1[0][0]
# ____________________________________________________________________________________________________
# Conv2d_23_1/relu (Activation)    (None, 7, 7, 1280)    0           Conv2d_23_1/batch_norm[0][0]
# ____________________________________________________________________________________________________
# top/GlobalPool (GlobalAveragePoo (None, 1280)          0           Conv2d_23_1/relu[0][0]
# ____________________________________________________________________________________________________
# top/Reshape (Reshape)            (None, 1, 1, 1280)    0           top/GlobalPool[0][0]
# ____________________________________________________________________________________________________
# top/Dropout (Dropout)            (None, 1, 1, 1280)    0           top/Reshape[0][0]
# ____________________________________________________________________________________________________
# top/Conv2d_1x1_output (Conv2D)   (None, 1, 1, 1001)    1282281     top/Dropout[0][0]
# ____________________________________________________________________________________________________
# top/SpatialSqueeze (Reshape)     (None, 1001)          0           top/Conv2d_1x1_output[0][0]
# ____________________________________________________________________________________________________
# top/Predictions (Activation)     (None, 1001)          0           top/SpatialSqueeze[0][0]
# ====================================================================================================
# Total params: 3,019,569
# Trainable params: 2,989,441
# Non-trainable params: 30,128
# ____________________________________________________________________________________________________

# %%
load_tf2_keras_model_weights(model, order_keras_weights, mobinetv3_tf1_tf2_name_convert)

# %%
model.compile(
    optimizer='rmsprop',
    loss=tf.keras.losses.categorical_crossentropy,
    metrics=[tf.keras.metrics.categorical_crossentropy])

save_format = 'ckpt'
save_path = '/Users/luoshixin/Downloads/mobilenet_v2_ck'

if save_format == 'ckpt':
    checkpoint = tf.train.Checkpoint(model=model)
    manager = tf.train.CheckpointManager(checkpoint,
                                         directory=save_path,
                                         max_to_keep=1)
    manager.save()
else:
    model.save(save_path, save_format=save_format)

# %%
d_config = _get_dataset_config().get("imagenette")()
d_config.split = 'validation'
eval_dataset = get_dataset(d_config)
for batch in eval_dataset.take(1):
    data = batch[0]

# %%
model.predict(data)
# Out:
# array([[7.8164230e-05, 2.8054435e-06, 3.7725473e-05, ..., 7.1818903e-07,
#         2.3649447e-06, 1.6855093e-04],
#        [1.7840277e-04, 6.9461362e-06, 2.0734682e-04, ..., 9.7580096e-06,
#         2.4597427e-06, 1.4878457e-04],
#        [1.3770195e-04, 7.7206741e-06, 3.9773171e-05, ..., 2.6971329e-05,
#         7.6665410e-06, 8.8319654e-04],
#        ...,
#        [1.5928911e-04, 1.7140999e-05, 8.1994373e-04, ..., 2.3085508e-06,
#         2.8840350e-06, 1.3298711e-05],
#        [1.2530814e-03, 3.2480626e-04, 7.9988514e-04, ..., 1.0357323e-03,
#         8.5979491e-04, 3.0377106e-04],
#        [1.5655537e-04, 8.2203505e-06, 1.9609186e-04, ..., 1.8550039e-05,
#         2.2085471e-05, 2.0344274e-03]], dtype=float32)

# %%
()
# Out:
# ()
